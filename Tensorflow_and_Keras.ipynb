# %% [markdown]
# <a href="https://colab.research.google.com/github/oussama016/deeplearning_tensorflow/blob/main/Tensorflow_and_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tensor flow and Keras

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.9.2

# %%
# to upload img from path
from tensorflow.keras.preprocessing.image import load_img

# %%
path  = 'C:/Users/oussama.belyamani/Downloads/tendor_labello'

# %% [markdown]
# the target size of the image must be one of 3 :
# * 299*299
# * 224*224
# * 150*150

# %%
# the target size of the image must be one of 3 :
#299*299
#224*224
#150*150
img = load_img('tendor_labello.png',target_size =(150,150))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7EFD677BDED0>

# %%
print(img)
# PIL stands for python image library
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7EFD677BDED0>

# %% [markdown]
# each image is a collection of pixels and each pixel is a combination of 3 colors :::
# * red 0-255
# * green 0-255
# * blue 0-255
# so a pixel can be represented by (Red , Green , Blue ) => (0-255 , 0-255 , 0-255 )
#
# an image is a combination of pixels , we can represent it by 3 araays/matrix ::
#
# for example image (150,150 )
# * image.shape = (150,150,3)
# * Red array.shape (150,150)
# * blue array.shape (150,150)
# * green array.shape (150,150)
# with values of each pixel between 0 and 255 .

# %%
np.array(img)
# we can see the array elements of the image.
# Out:
# array([[[ 75,  66,  57],
#         [ 76,  68,  57],
#         [ 58,  49,  40],
#         ...,
#         [ 41,  58,  76],
#         [ 28,  39,  59],
#         [ 23,  33,  58]],
#
#        [[ 62,  53,  44],
#         [ 68,  59,  50],
#         [ 77,  69,  58],
#         ...,
#         [ 36,  46,  73],
#         [ 24,  33,  62],
#         [ 26,  37,  55]],
#
#        [[ 69,  60,  51],
#         [ 63,  55,  44],
#         [ 70,  61,  52],
#         ...,
#         [ 23,  34,  56],
#         [ 38,  47,  64],
#         [ 46,  53,  79]],
#
#        ...,
#
#        [[201, 210, 191],
#         [200, 209, 190],
#         [207, 212, 192],
#         ...,
#         [199, 203, 188],
#         [200, 204, 189],
#         [199, 203, 188]],
#
#        [[202, 211, 192],
#         [204, 213, 194],
#         [204, 213, 196],
#         ...,
#         [200, 203, 192],
#         [198, 201, 190],
#         [200, 203, 192]],
#
#        [[204, 213, 194],
#         [206, 215, 196],
#         [207, 216, 199],
# ...

# %%
np.array(img).shape
# Out:
# (150, 150, 3)

# %% [markdown]
# # Pretrained convolutional neural network

# %%
from tensorflow.keras.applications.xception import Xception

# %%
Xception?

# %%
#model = Xception(weights='imagenet',input_shape=(299,299,3))
# Out:
# ...
# 91884032/91884032 [==============================] - 1s 0us/step

# %%
import pathlib
#dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
path  = "C:/Users/oussama.belyamani/Downloads/tendor_labello"
data_dir = tf.keras.utils.get_file(origin=path,
                                   fname='flower_photos')
data_dir = pathlib.Path(data_dir)

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-7e81249f-10aa-432d-ace6-1604df250c13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e81249f-10aa-432d-ace6-1604df250c13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
t = uploaded.keys()
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-1b7eae21c0ce> in <module>
#       1 t = uploaded.keys()
# ----> 2 t[0]
#
# TypeError: 'dict_keys' object is not subscriptable
